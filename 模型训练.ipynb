# %%
import numpy as np
import pandas as pd

# %%
a_2=pd.read_csv("F:\\firefoxdownload\\training\\training\\444.csv")

# %%
Y=a_2['flag']
X=a_2.drop(['flag'],axis=1)
X=X.drop(['id'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# rfc=RandomForestClassifier(random_state=30,n_estimators=243)
# rfc.fit(X,Y)

# %%
# rfc=RandomForestClassifier(n_estimators=243,random_state=90,max_depth=2,max_features=5)

# %%
#from sklearn.model_selection import cross_val_score

# %%
  #score=cross_val_score(rfc,X,Y,cv=10).mean()

# %%
#score

# %%
# scorel=[]
# for i in range(1,20,2):
#     rfc=RandomForestClassifier(n_estimators=243,random_state=90,max_features=5,max_depth=i)
#     score=cross_val_score(rfc,X,Y,cv=10).mean()
#     scorel.append(score)

# %%
# scorel

# %%
# score

# %%
 #rfc=RandomForestClassifier(n_estimators=243,random_state=90,max_depth=2,max_features=5)
rfc=RandomForestClassifier(n_estimators=500,random_state=90,max_depth=5)
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=5, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=90, verbose=0,
#                        warm_start=False)

# %%
rfc.score(X_test,Y_test)
# Out:
# 0.8082992402104032

# %%
t=rfc.predict(X_test)

# %%
list(t).count(1)
# Out:
# 893

# %%
X_t=pd.read_csv('F:\\firefoxdownload\\testb\\b\\b.csv')

# %%
x=X_t['id']

# %%
X_t=X_t.drop(['id'],axis=1)

# %%
a=rfc.predict(X_t)

# %%
b=list(a)

# %%
b.count(0)
# Out:
# 3816

# %%
b.count(1)
# Out:
# 184

# %%
a=rfc.predict_proba(X_t)

# %%
a
# Out:
# array([[0.57328512, 0.42671488],
#        [0.67611278, 0.32388722],
#        [0.63306843, 0.36693157],
#        ...,
#        [0.65538714, 0.34461286],
#        [0.60615434, 0.39384566],
#        [0.74201945, 0.25798055]])

# %%
a=a[:,1]

# %%
max(a)
# Out:
# 0.5683619463086259

# %%
f=open(r'C:\Users\admin\Desktop\11.txt',encoding='utf-8',mode='w')
for i in range(len(list(x))):
    print(str(list(x)[i])+'\t'+str(list(a)[i]),file=f)
f.close()

# %%
for i in range(len(list(x))):
    print(str(list(x)[i])+'\t'+str(list(a)[i]))
# Out:
# U1E63A3	0.41815874153002885
# U3EC77F	0.32026876399563126
# U27DC0C	0.35911435125437247
# U3FAAAC	0.2829418535471518
# U04EA0B	0.35338592024709986
# U41319C	0.46254040100482663
# U3DF7A7	0.36044528779681484
# U209ACC	0.2344841147840653
# U4A883D	0.26161929197556294
# U333BB1	0.20579771445926293
# U3606F7	0.41571806935525774
# U5237B1	0.4042536050033008
# U4CBDF4	0.4065284808607454
# U40C23B	0.3961912835145375
# U511B56	0.3749489885311472
# U2A8471	0.4345687698671991
# U319AA3	0.3471648161702872
# U02E468	0.42632468012744307
# U483869	0.4323444204535726
# U0A35B4	0.322850750034101
# U08FCA4	0.4500556589040919
# U3FE578	0.4039999004345641
# U03DC0B	0.40209956945880526
# U05E64A	0.3857965260453204
# U317424	0.4255329517610254
# U25A083	0.2978362107246955
# U1170DD	0.44863435632504545
# U22C251	0.3372915661093985
# U192810	0.35340681178163963
# U191DAF	0.4040561949333594
# U370A32	0.41857248973285904
# U17AE2E	0.413810911098759
# U08EE70	0.3782558577784484
# U465455	0.37466623109047953
# ...
